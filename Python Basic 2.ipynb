# %% [markdown]
# ### l=[ ] tuple=() dict={ }

# %%
lists=['1','2','3']
print(lists)
# Out:
# ['1', '2', '3']

# %%
lists[0]
# Out:
# '1'

# %%
lists[2]
# Out:
# '3'

# %%
lists[2]
# Out:
# '3'

# %%
lists[-1]
# Out:
# '3'

# %%
lists[1:3]
# Out:
# ['2', '3']

# %%
lists[:-1]
# Out:
# ['1', '2']

# %%
lists[:-2]
# Out:
# ['1']

# %%
print(lists)
# Out:
# ['1', '2', '3']

# %%
## remove,pop,delete,clear

# %%
lists.remove('2')

# %%
print(lists)
# Out:
# ['1', '3']

# %%
lists.remove('3')
print(lists)
# Out:
# ['1']

# %%
l2=['1','2','4','6','8','10','12']
print(l2)
# Out:
# ['1', '2', '4', '6', '8', '10', '12']

# %%
l2.append(14) # for single

# %%
print(l2)
# Out:
# ['1', '2', '4', '6', '8', '10', '12', 14]

# %%
l3=[18,20,48]
l2.extend(l3)
print(l2)
# Out:
# ['1', '2', '4', '6', '8', '10', '12', 14, 18, 20, 48]

# %%
l1=l2
print(l1)
# Out:
# ['1', '2', '4', '6', '8', '10', '12', 14, 18, 20, 48]

# %%
l2.clear()

# %%
print(l2)
# Out:
# []

# %%
l4=[1,2,4,5,8,9]

# %%
print(l4[:-1])
# Out:
# [9, 8, 5, 4, 2]

# %%
print(l4)
# Out:
# [9, 5, 4, 2, 1]

# %%
l4.pop(4)
# Out:
# 1

# %%
l4
# Out:
# [9, 5, 4, 2]

# %%
print(l4.index(9))
# Out:
# 0

# %%
print(l4.index(2))
# Out:
# 3

# %%
l4.append(8)

# %%
l5=[10,9,9]
l4.extend(l5)

# %%
l4
# Out:
# [9, 5, 4, 2, 8, 10, 9, 9]

# %%
print(l4.count(9))
# Out:
# 3

# %%
l4.append(8)

# %%
print(l4.count(8))
# Out:
# 2

# %%
l4.sort()

# %%
print(l4)
# Out:
# [2, 4, 5, 8, 8, 9, 9, 9, 10]

# %%
l4.reverse()

# %%
print(l4)
# Out:
# [10, 9, 9, 9, 8, 8, 5, 4, 2]

# %%
print(l4.index(9))
# Out:
# 1
